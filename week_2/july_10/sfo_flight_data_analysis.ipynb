# %%
import pandas as pd

df = pd.read_csv('sfo_flight_data.csv')
df
# Out:
#       DateTime  Scheduled flights  Tracked flights
# 0   2025-06-10                607              599
# 1   2025-06-11                603              590
# 2   2025-06-12                618              604
# 3   2025-06-13                627              617
# 4   2025-06-14                603              588
# 5   2025-06-15                606              595
# 6   2025-06-16                638              621
# 7   2025-06-17                612              601
# 8   2025-06-18                611              598
# 9   2025-06-19                610              595
# 10  2025-06-20                631              609
# 11  2025-06-21                594              587
# 12  2025-06-22                602              596
# 13  2025-06-23                625              619
# 14  2025-06-24                605              592
# 15  2025-06-25                591              583
# 16  2025-06-26                624              607
# ...
